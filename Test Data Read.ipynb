# %%
import h5py

# %%
filehandle = h5py.File('tests/data_api3/test2.h5', "r")

# %%
filehandle
# Out:
# <HDF5 file "test2.h5" (mode r)>

# %%
# Show file structure
filehandle.visititems(lambda x, y: print(x))
# Out:
# SARES11-SPEC125-M1:FPICTURE
# SARES11-SPEC125-M1:FPICTURE/data
# SARES11-SPEC125-M1:FPICTURE/pulse_id
# SARES11-SPEC125-M1:FPICTURE/timestamp

# %%
data = filehandle['SARES11-SPEC125-M1:FPICTURE/data']

# %%
data[2]
# Out:
# array([[ 96,  95,  92, ...,  94,  96,  97],
#        [ 97,  98, 104, ...,  95,  98,  75],
#        [105, 103, 105, ...,  97,  93, 100],
#        ...,
#        [101, 101, 100, ...,  96,  97,  96],
#        [ 97,  99,  96, ..., 107,  99,  95],
#        [100,  96,  94, ..., 100,  93,  92]], dtype=uint16)

# %%
data._filters
# Out:
# {'32008': (0, 3, 2, 8192, 2)}

# %%
# {'32008': (0, 2, 4, 2048, 2)}

# %%
filehandle.close()

# %%
import bitshuffle.h5

# %%
bitshuffle.h5.H5_COMPRESS_LZ4
# Out:
# 2

# %%
bitshuffle.h5.H5_COMPRESS_LZ4
# Out:
# 2

# %%
# Out:
# <function h5py._hl.filters.get_filters(plist)>

# %%
# https://stackoverflow.com/questions/37558523/converting-2d-numpy-array-of-grayscale-values-to-a-pil-image
from PIL import Image
import numpy as np
Image.fromarray(np.uint8(data[2] * 255) , 'L')
# Out:
# <PIL.Image.Image image mode=L size=2048x2048 at 0x11CAA8D10>

# %%
import matplotlib.pyplot as plt
# %matplotlib widget
plt.imshow(data[2], cmap="gray")
# plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
