# %%
import h5py
import bitshuffle.h5  # Register bitshuffle filter !!!!

# %%
filehandle = h5py.File('tests/data_api3/my.h5', "r")

# %%
filehandle
# Out:
# <HDF5 file "my.h5" (mode r)>

# %%
# Show file structure
filehandle.visititems(lambda x, y: print(x))
# Out:
# SARES11-SPEC125-M1:FPICTURE
# SARES11-SPEC125-M1:FPICTURE/data
# SARES11-SPEC125-M1:FPICTURE/pulse_id
# SARES11-SPEC125-M1:FPICTURE/timestamp

# %%
data = filehandle['SARES11-SPEC125-M1:FPICTURE/data']

# %%
data[2]
# Out:
# array([[ 94,  99,  94, ...,  94,  94,  96],
#        [ 99,  97,  98, ..., 102,  95,  95],
#        [ 90, 101,  96, ...,  96,  91,  95],
#        ...,
#        [ 99,  95,  97, ...,  98,  99,  98],
#        [ 99,  96,  96, ..., 100,  98,  93],
#        [ 95,  95,  94, ..., 124, 119, 103]], dtype=uint16)

# %%
data._filters
# Out:
# {'32008': (0, 3, 2, 8192, 2)}

# %%
# {'32008': (0, 2, 4, 2048, 2)}

# %%
# https://stackoverflow.com/questions/37558523/converting-2d-numpy-array-of-grayscale-values-to-a-pil-image
from PIL import Image
import numpy as np
Image.fromarray(np.uint8(data[2] * 255) , 'L')
# Out:
# <PIL.Image.Image image mode=L size=2048x2048 at 0x119155790>

# %%
import matplotlib.pyplot as plt
# %matplotlib widget
plt.imshow(data[2], cmap="gray")
# plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
filehandle.close()
