# %% [markdown]
# # Usage and Analysis Examples
#
# This notebook shows some basic manipulations that can be done with this module.
#
# First, let's import the plotting library (`matplotlib`) with a cool style

# %%
# %matplotlib nbagg
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# then, import the module, and create a `data_api` object

# %%
import data_api as api

# %% [markdown]
# You can start by searching for channels, e.g.:

# %%
api.search('FOR-PHASE-AVG')
# Out:
# [{'backend': 'sf-databuffer',
#   'channels': ['S10CB01-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB01-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB02-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB03-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB04-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB05-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB06-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB07-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB08-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RBOC-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RIQM-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RKLY-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RPRE-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S10CB09-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RBOC-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RIQM-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RKLY-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RPRE-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S20CB01-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RBOC-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RIQM-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RKLY-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RPRE-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S20CB02-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RBOC-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RIQM-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RKLY-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RPRE-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S30CB01-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RBOC-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RIQM-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RKLY-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RPRE-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S30CB02-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RBOC-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RIQM-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RKLY-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RPRE-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S30CB03-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RBOC-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RIQM-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RKLY-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RPRE-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S30CB04-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RBOC-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RIQM-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RKLY-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RPRE-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RWVG200-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RWVG300-DCP10:FOR-PHASE-AVG',
#    'S30CB13-RWVG400-DCP10:FOR-PHASE-AVG',
#    'S30CB14-RBOC-DCP10:FOR-PHASE-AVG',
#    'S30CB14-RIQM-DCP10:FOR-PHASE-AVG',
#    'S30CB14-RWVG100-DCP10:FOR-PHASE-AVG',
#    'S30CB14-RWVG200-DCP10:FOR-PHASE-AVG',
#    'SINDI01-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINDI01-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINDI01-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINDI01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINEG01-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINEG01-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINEG01-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINEG01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINSB01-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINSB01-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINSB01-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINSB01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINSB02-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINSB02-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINSB02-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINSB02-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINSB03-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINSB03-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINSB03-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINSB03-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINSB03-RWVG200-DCP10:FOR-PHASE-AVG',
#    'SINSB04-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINSB04-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINSB04-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINSB04-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINSB04-RWVG200-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RIQM-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RIQM-DCP20:FOR-PHASE-AVG',
#    'SINXB01-RKLY-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RLOD100-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RLOD200-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RPRE-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RWVG100-DCP10:FOR-PHASE-AVG',
#    'SINXB01-RWVG200-DCP10:FOR-PHASE-AVG']},
#  {'backend': 'sf-archiverappliance',
#   'channels': ['S10CB01-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB01-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB02-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB03-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB04-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB05-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB06-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB07-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB08-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S10CB09-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB01-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB02-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S20CB03-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB01-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB02-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB03-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB04-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB05-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB06-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RWVG300-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB13-RWVG400-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB14-RBOC-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB14-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB14-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'S30CB14-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'SINDI01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINDI01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINDI01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINDI01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINEG01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINEG01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINEG01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINEG01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB02-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB02-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB02-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB02-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB03-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB03-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB03-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB03-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB03-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB04-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB04-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB04-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB04-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINSB04-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RIQM-DCP20:FOR-PHASE-AVG-P2P',
#    'SINXB01-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RLOD100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RLOD200-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RPRE-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RWVG100-DCP10:FOR-PHASE-AVG-P2P',
#    'SINXB01-RWVG200-DCP10:FOR-PHASE-AVG-P2P',
#    'SWBGB-RIQM-DCP10:FOR-PHASE-AVG',
#    'SWBGB-RIQM-DCP10:FOR-PHASE-AVG-P2P',
#    'SWBGB-RKLY-DCP10:FOR-PHASE-AVG',
#    'SWBGB-RKLY-DCP10:FOR-PHASE-AVG-P2P',
#    'SWBGB-RKLY-DCP20:FOR-PHASE-AVG',
#    'SWBGB-RKLY-DCP20:FOR-PHASE-AVG-P2P',
#    'SWBGB-RLOD100-DCP10:FOR-PHASE-AVG',
#    'SWBGB-RLOD100-DCP10:FOR-PHASE-AVG-P2P']}]

# %% [markdown]
# Then, you can get data from some channels, within a certain range. Ranges can be of type:
# * `date`: e.g. "2016-07-26 16:00"
# * `globalSeconds`
# * `pulseId`
#
# You can select a range start, end, or delta (two of the three). You can also decide if the table should be indexed accordingly to `date`, `globalSeconds` or `pulseId`

# %%
data = api.get_data(channels=[
        'SINSB02-RIQM-DCP10:FOR-PHASE-AVG', 
        'SINDI01-RIQM-DCP10:FOR-PHASE-AVG', 
        'S10CB01-RIQM-DCP10:FOR-PHASE-AVG',
       ], start="2016-07-27 16:11", end="2016-07-27 16:12")
# Out:
# [INFO] Querying channels: ['SINSB02-RIQM-DCP10:FOR-PHASE-AVG', 'SINDI01-RIQM-DCP10:FOR-PHASE-AVG', 'S10CB01-RIQM-DCP10:FOR-PHASE-AVG']
# [INFO] Querying on globalDate between 2016-07-27 16:11 and 2016-07-27 16:12

# %% [markdown]
# Then, let's just explore the first 5 elements:

# %%
data.head()
# Out:
#                                       pulseId  globalSeconds  eventCount  \
# globalDate
# 2016-07-27T16:11:00.663907900+02:00  43907900 1469628660.663           1
# 2016-07-27T16:11:01.663908000+02:00  43908000 1469628661.663           1
# 2016-07-27T16:11:02.663908100+02:00  43908100 1469628662.663           1
# 2016-07-27T16:11:03.663908200+02:00  43908200 1469628663.663           1
# 2016-07-27T16:11:04.663908300+02:00  43908300 1469628664.663           1
#
#                                      SINSB02-RIQM-DCP10:FOR-PHASE-AVG  \
# globalDate
# 2016-07-27T16:11:00.663907900+02:00                           -48.028
# 2016-07-27T16:11:01.663908000+02:00                           -48.026
# 2016-07-27T16:11:02.663908100+02:00                           -48.028
# 2016-07-27T16:11:03.663908200+02:00                           -48.029
# 2016-07-27T16:11:04.663908300+02:00                           -48.023
#
#                                      SINDI01-RIQM-DCP10:FOR-PHASE-AVG  \
# globalDate
# 2016-07-27T16:11:00.663907900+02:00                            58.474
# 2016-07-27T16:11:01.663908000+02:00                            58.479
# 2016-07-27T16:11:02.663908100+02:00                            58.476
# 2016-07-27T16:11:03.663908200+02:00                            58.476
# 2016-07-27T16:11:04.663908300+02:00                            58.475
#
#                                      S10CB01-RIQM-DCP10:FOR-PHASE-AVG  \
# globalDate
# 2016-07-27T16:11:00.663907900+02:00                           144.507
# 2016-07-27T16:11:01.663908000+02:00                           144.424
# 2016-07-27T16:11:02.663908100+02:00                           144.460
# 2016-07-27T16:11:03.663908200+02:00                           144.455
# 2016-07-27T16:11:04.663908300+02:00                           144.480
#
#                                      globalNanoseconds
# globalDate
# 2016-07-27T16:11:00.663907900+02:00             907900
# 2016-07-27T16:11:01.663908000+02:00             908000
# 2016-07-27T16:11:02.663908100+02:00             908100
# 2016-07-27T16:11:03.663908200+02:00             908200
# 2016-07-27T16:11:04.663908300+02:00             908300

# %% [markdown]
# ## Plotting
#
# Pandas comes with some nice plotting utilities based on `matplotlib`:

# %%
data.plot(style='.-')

# %% [markdown]
# Also, doing a *box* plot is extremely easy:

# %%
data.plot(kind='box')

# %% [markdown]
# There are also some tools for more complex plotting, like a *scatter matrix* plus KDE estimation:

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(data, alpha=0.2, figsize=(10, 10), diagonal='kde')
# Out:
# /Users/ebner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ebner/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   'left=%s, right=%s') % (left, right))
# /Users/ebner/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3239: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-8-aaaf0e081377> in <module>()
#       1 from pandas.tools.plotting import scatter_matrix
#       2
# ----> 3 scatter_matrix(data, alpha=0.2, figsize=(10, 10), diagonal='kde')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/tools/plotting.py in wrapper(*args, **kwargs)
#      15                           "import 'pandas.plotting.{t}' instead.".format(t=t),
#      16                           FutureWarning, stacklevel=2)
# ---> 17             return getattr(_plotting, t)(*args, **kwargs)
#      18         return wrapper
#      19
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      94                     from scipy.stats import gaussian_kde
#      95                     y = values
# ---> 96                     gkde = gaussian_kde(y)
#      97                     ind = np.linspace(y.min(), y.max(), 1000)
#      98                     ax.plot(ind, gkde.evaluate(ind), **density_kwds)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method)
#     170
#     171         self.d, self.n = self.dataset.shape
# --> 172         self.set_bandwidth(bw_method=bw_method)
#     173
#     174     def evaluate(self, points):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     497             raise ValueError(msg)
#     498
# --> 499         self._compute_covariance()
#     500
#     501     def _compute_covariance(self):
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     508             self._data_covariance = atleast_2d(np.cov(self.dataset, rowvar=1,
#     509                                                bias=False))
# --> 510             self._data_inv_cov = linalg.inv(self._data_covariance)
#     511
#     512         self.covariance = self._data_covariance * self.factor**2
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     817         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     818     if info > 0:
# --> 819         raise LinAlgError("singular matrix")
#     820     if info < 0:
#     821         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix

# %% [markdown]
# More examples can be found here: http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %% [markdown]
# ## Data reduction
#
# You can reduce the data using the API (NB: at the moment, client side aggregation is always performed: this will change in the future):
# * first, you configure the aggregation
# * then, you retrieve data

# %%
from data_api.client import Aggregation
reduced_data = api.get_data(channels=[
        'SINSB02-RIQM-DCP10:FOR-PHASE-AVG', 
        'SINDI01-RIQM-DCP10:FOR-PHASE-AVG', 
        'S10CB01-RIQM-DCP10:FOR-PHASE-AVG',
       ], 
                  start="2017-11-27 16:11", end="2017-11-27 16:12", 
                  index_field="pulseId", aggregation=Aggregation(aggregations=["min", "mean", "max"]))
# Out:
# [INFO] Querying channels: ['SINSB02-RIQM-DCP10:FOR-PHASE-AVG', 'SINDI01-RIQM-DCP10:FOR-PHASE-AVG', 'S10CB01-RIQM-DCP10:FOR-PHASE-AVG']
# [INFO] Querying on globalDate between 2017-11-27 16:11 and 2017-11-27 16:12

# %%
reduced_data.columns
# Out:
# Index(['globalSeconds', 'globalDate', 'eventCount',
#        'SINSB02-RIQM-DCP10:FOR-PHASE-AVG:max',
#        'SINSB02-RIQM-DCP10:FOR-PHASE-AVG:mean',
#        'SINSB02-RIQM-DCP10:FOR-PHASE-AVG:min',
#        'SINDI01-RIQM-DCP10:FOR-PHASE-AVG:max',
#        'SINDI01-RIQM-DCP10:FOR-PHASE-AVG:mean',
#        'SINDI01-RIQM-DCP10:FOR-PHASE-AVG:min',
#        'S10CB01-RIQM-DCP10:FOR-PHASE-AVG:max',
#        'S10CB01-RIQM-DCP10:FOR-PHASE-AVG:mean',
#        'S10CB01-RIQM-DCP10:FOR-PHASE-AVG:min', 'globalNanoseconds'],
#       dtype='object')

# %%
reduced_data
# Out:
#             globalSeconds                           globalDate  eventCount  \
# pulseId
# 4072906840 1511795460.061  2017-11-27T16:11:00.061906840+01:00           1
# 4072906850 1511795460.161  2017-11-27T16:11:00.161906850+01:00           1
# 4072906860 1511795460.261  2017-11-27T16:11:00.261906860+01:00           1
# 4072906870 1511795460.361  2017-11-27T16:11:00.361906870+01:00           1
# 4072906880 1511795460.461  2017-11-27T16:11:00.461906880+01:00           1
# 4072906890 1511795460.561  2017-11-27T16:11:00.561906890+01:00           1
# 4072906900 1511795460.661  2017-11-27T16:11:00.661906900+01:00           1
# 4072906910 1511795460.761  2017-11-27T16:11:00.761906910+01:00           1
# 4072906920 1511795460.861  2017-11-27T16:11:00.861906920+01:00           1
# 4072906930 1511795460.961  2017-11-27T16:11:00.961906930+01:00           1
# 4072906940 1511795461.061  2017-11-27T16:11:01.061906940+01:00           1
# 4072906950 1511795461.161  2017-11-27T16:11:01.161906950+01:00           1
# 4072906960 1511795461.261  2017-11-27T16:11:01.261906960+01:00           1
# 4072906970 1511795461.361  2017-11-27T16:11:01.361906970+01:00           1
# 4072906980 1511795461.461  2017-11-27T16:11:01.461906980+01:00           1
# 4072906990 1511795461.561  2017-11-27T16:11:01.561906990+01:00           1
# 4072907000 1511795461.661  2017-11-27T16:11:01.661907000+01:00           1
# 4072907010 1511795461.761  2017-11-27T16:11:01.761907010+01:00           1
# 4072907020 1511795461.861  2017-11-27T16:11:01.861907020+01:00           1
# 4072907030 1511795461.961  2017-11-27T16:11:01.961907030+01:00           1
# 4072907040 1511795462.061  2017-11-27T16:11:02.061907040+01:00           1
# 4072907050 1511795462.161  2017-11-27T16:11:02.161907050+01:00           1
# 4072907060 1511795462.261  2017-11-27T16:11:02.261907060+01:00           1
# 4072907070 1511795462.361  2017-11-27T16:11:02.361907070+01:00           1
# 4072907080 1511795462.461  2017-11-27T16:11:02.461907080+01:00           1
# 4072907090 1511795462.561  2017-11-27T16:11:02.561907090+01:00           1
# 4072907100 1511795462.661  2017-11-27T16:11:02.661907100+01:00           1
# 4072907110 1511795462.761  2017-11-27T16:11:02.761907110+01:00           1
# 4072907120 1511795462.861  2017-11-27T16:11:02.861907120+01:00           1
# 4072907130 1511795462.961  2017-11-27T16:11:02.961907130+01:00           1
# ...                   ...                                  ...         ...
# 4072912540 1511795517.065  2017-11-27T16:11:57.065912540+01:00           1
# 4072912550 1511795517.165  2017-11-27T16:11:57.165912550+01:00           1
# 4072912560 1511795517.265  2017-11-27T16:11:57.265912560+01:00           1
# 4072912570 1511795517.365  2017-11-27T16:11:57.365912570+01:00           1
# 4072912580 1511795517.465  2017-11-27T16:11:57.465912580+01:00           1
# 4072912590 1511795517.564  2017-11-27T16:11:57.564912590+01:00           1
# 4072912600 1511795517.664  2017-11-27T16:11:57.664912600+01:00           1
# 4072912610 1511795517.764  2017-11-27T16:11:57.764912610+01:00           1
# 4072912620 1511795517.864  2017-11-27T16:11:57.864912620+01:00           1
# 4072912630 1511795517.964  2017-11-27T16:11:57.964912630+01:00           1
# 4072912640 1511795518.064  2017-11-27T16:11:58.064912640+01:00           1
# 4072912650 1511795518.164  2017-11-27T16:11:58.164912650+01:00           1
# 4072912660 1511795518.264  2017-11-27T16:11:58.264912660+01:00           1
# 4072912670 1511795518.364  2017-11-27T16:11:58.364912670+01:00           1
# 4072912680 1511795518.464  2017-11-27T16:11:58.464912680+01:00           1
# 4072912690 1511795518.564  2017-11-27T16:11:58.564912690+01:00           1
# 4072912700 1511795518.664  2017-11-27T16:11:58.664912700+01:00           1
# 4072912710 1511795518.764  2017-11-27T16:11:58.764912710+01:00           1
# 4072912720 1511795518.864  2017-11-27T16:11:58.864912720+01:00           1
# 4072912730 1511795518.964  2017-11-27T16:11:58.964912730+01:00           1
# 4072912740 1511795519.064  2017-11-27T16:11:59.064912740+01:00           1
# 4072912750 1511795519.164  2017-11-27T16:11:59.164912750+01:00           1
# 4072912760 1511795519.264  2017-11-27T16:11:59.264912760+01:00           1
# 4072912770 1511795519.364  2017-11-27T16:11:59.364912770+01:00           1
# 4072912780 1511795519.464  2017-11-27T16:11:59.464912780+01:00           1
# 4072912790 1511795519.564  2017-11-27T16:11:59.564912790+01:00           1
# 4072912800 1511795519.664  2017-11-27T16:11:59.664912800+01:00           1
# 4072912810 1511795519.764  2017-11-27T16:11:59.764912810+01:00           1
# 4072912820 1511795519.864  2017-11-27T16:11:59.864912820+01:00           1
# 4072912830 1511795519.964  2017-11-27T16:11:59.964912830+01:00           1
#
#             SINSB02-RIQM-DCP10:FOR-PHASE-AVG:max  \
# pulseId
# 4072906840                              -120.126
# 4072906850                              -120.126
# 4072906860                              -120.134
# 4072906870                              -120.130
# 4072906880                              -120.132
# 4072906890                              -120.128
# 4072906900                              -120.133
# 4072906910                              -120.130
# 4072906920                              -120.129
# 4072906930                              -120.132
# 4072906940                              -120.128
# 4072906950                              -120.124
# 4072906960                              -120.130
# 4072906970                              -120.130
# 4072906980                              -120.126
# 4072906990                              -120.124
# 4072907000                              -120.119
# 4072907010                              -120.137
# 4072907020                              -120.143
# 4072907030                              -120.137
# 4072907040                              -120.133
# 4072907050                              -120.135
# 4072907060                              -120.136
# 4072907070                              -120.133
# 4072907080                              -120.129
# 4072907090                              -120.129
# 4072907100                              -120.129
# 4072907110                              -120.145
# 4072907120                              -120.134
# 4072907130                              -120.134
# ...                                          ...
# 4072912540                              -120.095
# 4072912550                              -120.095
# 4072912560                              -120.102
# 4072912570                              -120.117
# 4072912580                              -120.102
# 4072912590                              -120.111
# 4072912600                              -120.100
# 4072912610                              -120.101
# 4072912620                              -120.103
# 4072912630                              -120.092
# 4072912640                              -120.103
# 4072912650                              -120.104
# 4072912660                              -120.105
# 4072912670                              -120.107
# 4072912680                              -120.090
# 4072912690                              -120.090
# 4072912700                              -120.106
# 4072912710                              -120.110
# 4072912720                              -120.092
# 4072912730                              -120.090
# 4072912740                              -120.091
# 4072912750                              -120.096
# 4072912760                              -120.090
# 4072912770                              -120.091
# 4072912780                              -120.094
# 4072912790                              -120.103
# 4072912800                              -120.104
# 4072912810                              -120.093
# 4072912820                              -120.096
# 4072912830                              -120.094
#
#             SINSB02-RIQM-DCP10:FOR-PHASE-AVG:mean  \
# pulseId
# 4072906840                               -120.126
# 4072906850                               -120.126
# 4072906860                               -120.134
# 4072906870                               -120.130
# 4072906880                               -120.132
# 4072906890                               -120.128
# 4072906900                               -120.133
# 4072906910                               -120.130
# 4072906920                               -120.129
# 4072906930                               -120.132
# 4072906940                               -120.128
# 4072906950                               -120.124
# 4072906960                               -120.130
# 4072906970                               -120.130
# 4072906980                               -120.126
# 4072906990                               -120.124
# 4072907000                               -120.119
# 4072907010                               -120.137
# 4072907020                               -120.143
# 4072907030                               -120.137
# 4072907040                               -120.133
# 4072907050                               -120.135
# 4072907060                               -120.136
# 4072907070                               -120.133
# 4072907080                               -120.129
# 4072907090                               -120.129
# 4072907100                               -120.129
# 4072907110                               -120.145
# 4072907120                               -120.134
# 4072907130                               -120.134
# ...                                           ...
# 4072912540                               -120.095
# 4072912550                               -120.095
# 4072912560                               -120.102
# 4072912570                               -120.117
# 4072912580                               -120.102
# 4072912590                               -120.111
# 4072912600                               -120.100
# 4072912610                               -120.101
# 4072912620                               -120.103
# 4072912630                               -120.092
# 4072912640                               -120.103
# 4072912650                               -120.104
# 4072912660                               -120.105
# 4072912670                               -120.107
# 4072912680                               -120.090
# 4072912690                               -120.090
# 4072912700                               -120.106
# 4072912710                               -120.110
# 4072912720                               -120.092
# 4072912730                               -120.090
# 4072912740                               -120.091
# 4072912750                               -120.096
# 4072912760                               -120.090
# 4072912770                               -120.091
# 4072912780                               -120.094
# 4072912790                               -120.103
# 4072912800                               -120.104
# 4072912810                               -120.093
# 4072912820                               -120.096
# 4072912830                               -120.094
#
#             SINSB02-RIQM-DCP10:FOR-PHASE-AVG:min  \
# pulseId
# 4072906840                              -120.126
# 4072906850                              -120.126
# 4072906860                              -120.134
# 4072906870                              -120.130
# 4072906880                              -120.132
# 4072906890                              -120.128
# 4072906900                              -120.133
# 4072906910                              -120.130
# 4072906920                              -120.129
# 4072906930                              -120.132
# 4072906940                              -120.128
# 4072906950                              -120.124
# 4072906960                              -120.130
# 4072906970                              -120.130
# 4072906980                              -120.126
# 4072906990                              -120.124
# 4072907000                              -120.119
# 4072907010                              -120.137
# 4072907020                              -120.143
# 4072907030                              -120.137
# 4072907040                              -120.133
# 4072907050                              -120.135
# 4072907060                              -120.136
# 4072907070                              -120.133
# 4072907080                              -120.129
# 4072907090                              -120.129
# 4072907100                              -120.129
# 4072907110                              -120.145
# 4072907120                              -120.134
# 4072907130                              -120.134
# ...                                          ...
# 4072912540                              -120.095
# 4072912550                              -120.095
# 4072912560                              -120.102
# 4072912570                              -120.117
# 4072912580                              -120.102
# 4072912590                              -120.111
# 4072912600                              -120.100
# 4072912610                              -120.101
# 4072912620                              -120.103
# 4072912630                              -120.092
# 4072912640                              -120.103
# 4072912650                              -120.104
# 4072912660                              -120.105
# 4072912670                              -120.107
# 4072912680                              -120.090
# 4072912690                              -120.090
# 4072912700                              -120.106
# 4072912710                              -120.110
# 4072912720                              -120.092
# 4072912730                              -120.090
# 4072912740                              -120.091
# 4072912750                              -120.096
# 4072912760                              -120.090
# 4072912770                              -120.091
# 4072912780                              -120.094
# 4072912790                              -120.103
# 4072912800                              -120.104
# 4072912810                              -120.093
# 4072912820                              -120.096
# 4072912830                              -120.094
#
#             SINDI01-RIQM-DCP10:FOR-PHASE-AVG:max  \
# pulseId
# 4072906840                              -127.693
# 4072906850                              -127.693
# 4072906860                              -127.686
# 4072906870                              -127.688
# 4072906880                              -127.691
# 4072906890                              -127.681
# 4072906900                              -127.690
# 4072906910                              -127.690
# 4072906920                              -127.686
# 4072906930                              -127.694
# 4072906940                              -127.686
# 4072906950                              -127.691
# 4072906960                              -127.687
# 4072906970                              -127.691
# 4072906980                              -127.687
# 4072906990                              -127.687
# 4072907000                              -127.691
# 4072907010                              -127.687
# 4072907020                              -127.687
# 4072907030                              -127.680
# 4072907040                              -127.691
# 4072907050                              -127.682
# 4072907060                              -127.678
# 4072907070                              -127.680
# 4072907080                              -127.681
# 4072907090                              -127.687
# 4072907100                              -127.685
# 4072907110                              -127.685
# 4072907120                              -127.688
# 4072907130                              -127.688
# ...                                          ...
# 4072912540                              -127.687
# 4072912550                              -127.694
# 4072912560                              -127.693
# 4072912570                              -127.694
# 4072912580                              -127.685
# 4072912590                              -127.689
# 4072912600                              -127.693
# 4072912610                              -127.677
# 4072912620                              -127.683
# 4072912630                              -127.698
# 4072912640                              -127.692
# 4072912650                              -127.695
# 4072912660                              -127.684
# 4072912670                              -127.693
# 4072912680                              -127.683
# 4072912690                              -127.691
# 4072912700                              -127.693
# 4072912710                              -127.699
# 4072912720                              -127.686
# 4072912730                              -127.691
# 4072912740                              -127.697
# 4072912750                              -127.698
# 4072912760                              -127.700
# 4072912770                              -127.688
# 4072912780                              -127.683
# 4072912790                              -127.692
# 4072912800                              -127.688
# 4072912810                              -127.685
# 4072912820                              -127.680
# 4072912830                              -127.680
#
#             SINDI01-RIQM-DCP10:FOR-PHASE-AVG:mean  \
# pulseId
# 4072906840                               -127.693
# 4072906850                               -127.693
# 4072906860                               -127.686
# 4072906870                               -127.688
# 4072906880                               -127.691
# 4072906890                               -127.681
# 4072906900                               -127.690
# 4072906910                               -127.690
# 4072906920                               -127.686
# 4072906930                               -127.694
# 4072906940                               -127.686
# 4072906950                               -127.691
# 4072906960                               -127.687
# 4072906970                               -127.691
# 4072906980                               -127.687
# 4072906990                               -127.687
# 4072907000                               -127.691
# 4072907010                               -127.687
# 4072907020                               -127.687
# 4072907030                               -127.680
# 4072907040                               -127.691
# 4072907050                               -127.682
# 4072907060                               -127.678
# 4072907070                               -127.680
# 4072907080                               -127.681
# 4072907090                               -127.687
# 4072907100                               -127.685
# 4072907110                               -127.685
# 4072907120                               -127.688
# 4072907130                               -127.688
# ...                                           ...
# 4072912540                               -127.687
# 4072912550                               -127.694
# 4072912560                               -127.693
# 4072912570                               -127.694
# 4072912580                               -127.685
# 4072912590                               -127.689
# 4072912600                               -127.693
# 4072912610                               -127.677
# 4072912620                               -127.683
# 4072912630                               -127.698
# 4072912640                               -127.692
# 4072912650                               -127.695
# 4072912660                               -127.684
# 4072912670                               -127.693
# 4072912680                               -127.683
# 4072912690                               -127.691
# 4072912700                               -127.693
# 4072912710                               -127.699
# 4072912720                               -127.686
# 4072912730                               -127.691
# 4072912740                               -127.697
# 4072912750                               -127.698
# 4072912760                               -127.700
# 4072912770                               -127.688
# 4072912780                               -127.683
# 4072912790                               -127.692
# 4072912800                               -127.688
# 4072912810                               -127.685
# 4072912820                               -127.680
# 4072912830                               -127.680
#
#             SINDI01-RIQM-DCP10:FOR-PHASE-AVG:min  \
# pulseId
# 4072906840                              -127.693
# 4072906850                              -127.693
# 4072906860                              -127.686
# 4072906870                              -127.688
# 4072906880                              -127.691
# 4072906890                              -127.681
# 4072906900                              -127.690
# 4072906910                              -127.690
# 4072906920                              -127.686
# 4072906930                              -127.694
# 4072906940                              -127.686
# 4072906950                              -127.691
# 4072906960                              -127.687
# 4072906970                              -127.691
# 4072906980                              -127.687
# 4072906990                              -127.687
# 4072907000                              -127.691
# 4072907010                              -127.687
# 4072907020                              -127.687
# 4072907030                              -127.680
# 4072907040                              -127.691
# 4072907050                              -127.682
# 4072907060                              -127.678
# 4072907070                              -127.680
# 4072907080                              -127.681
# 4072907090                              -127.687
# 4072907100                              -127.685
# 4072907110                              -127.685
# 4072907120                              -127.688
# 4072907130                              -127.688
# ...                                          ...
# 4072912540                              -127.687
# 4072912550                              -127.694
# 4072912560                              -127.693
# 4072912570                              -127.694
# 4072912580                              -127.685
# 4072912590                              -127.689
# 4072912600                              -127.693
# 4072912610                              -127.677
# 4072912620                              -127.683
# 4072912630                              -127.698
# 4072912640                              -127.692
# 4072912650                              -127.695
# 4072912660                              -127.684
# 4072912670                              -127.693
# 4072912680                              -127.683
# 4072912690                              -127.691
# 4072912700                              -127.693
# 4072912710                              -127.699
# 4072912720                              -127.686
# 4072912730                              -127.691
# 4072912740                              -127.697
# 4072912750                              -127.698
# 4072912760                              -127.700
# 4072912770                              -127.688
# 4072912780                              -127.683
# 4072912790                              -127.692
# 4072912800                              -127.688
# 4072912810                              -127.685
# 4072912820                              -127.680
# 4072912830                              -127.680
#
#             S10CB01-RIQM-DCP10:FOR-PHASE-AVG:max  \
# pulseId
# 4072906840                                49.166
# 4072906850                                49.173
# 4072906860                                49.171
# 4072906870                                49.171
# 4072906880                                49.172
# 4072906890                                49.168
# 4072906900                                49.171
# 4072906910                                49.161
# 4072906920                                49.161
# 4072906930                                49.169
# 4072906940                                49.176
# 4072906950                                49.164
# 4072906960                                49.173
# 4072906970                                49.166
# 4072906980                                49.160
# 4072906990                                49.168
# 4072907000                                49.164
# 4072907010                                49.160
# 4072907020                                49.168
# 4072907030                                49.168
# 4072907040                                49.182
# 4072907050                                49.168
# 4072907060                                49.174
# 4072907070                                49.164
# 4072907080                                49.177
# 4072907090                                49.158
# 4072907100                                49.176
# 4072907110                                49.165
# 4072907120                                49.172
# 4072907130                                49.159
# ...                                          ...
# 4072912540                                49.159
# 4072912550                                49.162
# 4072912560                                49.160
# 4072912570                                49.147
# 4072912580                                49.165
# 4072912590                                49.156
# 4072912600                                49.158
# 4072912610                                49.156
# 4072912620                                49.158
# 4072912630                                49.149
# 4072912640                                49.155
# 4072912650                                49.154
# 4072912660                                49.164
# 4072912670                                49.165
# 4072912680                                49.173
# 4072912690                                49.151
# 4072912700                                49.160
# 4072912710                                49.170
# 4072912720                                49.169
# 4072912730                                49.158
# 4072912740                                49.168
# 4072912750                                49.163
# 4072912760                                49.164
# 4072912770                                49.163
# 4072912780                                49.166
# 4072912790                                49.155
# 4072912800                                49.159
# 4072912810                                49.177
# 4072912820                                49.163
# 4072912830                                49.161
#
#             S10CB01-RIQM-DCP10:FOR-PHASE-AVG:mean  \
# pulseId
# 4072906840                                 49.166
# 4072906850                                 49.173
# 4072906860                                 49.171
# 4072906870                                 49.171
# 4072906880                                 49.172
# 4072906890                                 49.168
# 4072906900                                 49.171
# 4072906910                                 49.161
# 4072906920                                 49.161
# 4072906930                                 49.169
# 4072906940                                 49.176
# 4072906950                                 49.164
# 4072906960                                 49.173
# 4072906970                                 49.166
# 4072906980                                 49.160
# 4072906990                                 49.168
# 4072907000                                 49.164
# 4072907010                                 49.160
# 4072907020                                 49.168
# 4072907030                                 49.168
# 4072907040                                 49.182
# 4072907050                                 49.168
# 4072907060                                 49.174
# 4072907070                                 49.164
# 4072907080                                 49.177
# 4072907090                                 49.158
# 4072907100                                 49.176
# 4072907110                                 49.165
# 4072907120                                 49.172
# 4072907130                                 49.159
# ...                                           ...
# 4072912540                                 49.159
# 4072912550                                 49.162
# 4072912560                                 49.160
# 4072912570                                 49.147
# 4072912580                                 49.165
# 4072912590                                 49.156
# 4072912600                                 49.158
# 4072912610                                 49.156
# 4072912620                                 49.158
# 4072912630                                 49.149
# 4072912640                                 49.155
# 4072912650                                 49.154
# 4072912660                                 49.164
# 4072912670                                 49.165
# 4072912680                                 49.173
# 4072912690                                 49.151
# 4072912700                                 49.160
# 4072912710                                 49.170
# 4072912720                                 49.169
# 4072912730                                 49.158
# 4072912740                                 49.168
# 4072912750                                 49.163
# 4072912760                                 49.164
# 4072912770                                 49.163
# 4072912780                                 49.166
# 4072912790                                 49.155
# 4072912800                                 49.159
# 4072912810                                 49.177
# 4072912820                                 49.163
# 4072912830                                 49.161
#
#             S10CB01-RIQM-DCP10:FOR-PHASE-AVG:min  globalNanoseconds
# pulseId
# 4072906840                                49.166             906840
# 4072906850                                49.173             906850
# 4072906860                                49.171             906860
# 4072906870                                49.171             906870
# 4072906880                                49.172             906880
# 4072906890                                49.168             906890
# 4072906900                                49.171             906900
# 4072906910                                49.161             906910
# 4072906920                                49.161             906920
# 4072906930                                49.169             906930
# 4072906940                                49.176             906940
# 4072906950                                49.164             906950
# 4072906960                                49.173             906960
# 4072906970                                49.166             906970
# 4072906980                                49.160             906980
# 4072906990                                49.168             906990
# 4072907000                                49.164             907000
# 4072907010                                49.160             907010
# 4072907020                                49.168             907020
# 4072907030                                49.168             907030
# 4072907040                                49.182             907040
# 4072907050                                49.168             907050
# 4072907060                                49.174             907060
# 4072907070                                49.164             907070
# 4072907080                                49.177             907080
# 4072907090                                49.158             907090
# 4072907100                                49.176             907100
# 4072907110                                49.165             907110
# 4072907120                                49.172             907120
# 4072907130                                49.159             907130
# ...                                          ...                ...
# 4072912540                                49.159             912540
# 4072912550                                49.162             912550
# 4072912560                                49.160             912560
# 4072912570                                49.147             912570
# 4072912580                                49.165             912580
# 4072912590                                49.156             912590
# 4072912600                                49.158             912600
# 4072912610                                49.156             912610
# 4072912620                                49.158             912620
# 4072912630                                49.149             912630
# 4072912640                                49.155             912640
# 4072912650                                49.154             912650
# 4072912660                                49.164             912660
# 4072912670                                49.165             912670
# 4072912680                                49.173             912680
# 4072912690                                49.151             912690
# 4072912700                                49.160             912700
# 4072912710                                49.170             912710
# 4072912720                                49.169             912720
# 4072912730                                49.158             912730
# 4072912740                                49.168             912740
# 4072912750                                49.163             912750
# 4072912760                                49.164             912760
# 4072912770                                49.163             912770
# 4072912780                                49.166             912780
# 4072912790                                49.155             912790
# 4072912800                                49.159             912800
# 4072912810                                49.177             912810
# 4072912820                                49.163             912820
# 4072912830                                49.161             912830
#
# [600 rows x 13 columns]

# %%
quantities = ['SINSB02-RIQM-DCP10:FOR-PHASE-AVG:max',
              'SINDI01-RIQM-DCP10:FOR-PHASE-AVG:max',
              'S10CB01-RIQM-DCP10:FOR-PHASE-AVG:max']
reduced_data[quantities].plot()

# %% [markdown]
# You can also do a lot of statistics directly on the client! In case you are wondering about mean and standard deviation of the sample:

# %%
data.mean(), data.std()
# Out:
# (pulseId                              43910850.000
#  globalSeconds                      1469628690.167
#  eventCount                                  1.000
#  SINSB02-RIQM-DCP10:FOR-PHASE-AVG          -48.030
#  SINDI01-RIQM-DCP10:FOR-PHASE-AVG           58.469
#  S10CB01-RIQM-DCP10:FOR-PHASE-AVG          144.486
#  globalNanoseconds                      910850.000
#  dtype: float64, pulseId                            1746.425
#  globalSeconds                        17.467
#  eventCount                            0.000
#  SINSB02-RIQM-DCP10:FOR-PHASE-AVG      0.004
#  SINDI01-RIQM-DCP10:FOR-PHASE-AVG      0.006
#  S10CB01-RIQM-DCP10:FOR-PHASE-AVG      0.018
#  globalNanoseconds                  1746.425
#  dtype: float64)

# %% [markdown]
# You can also rebin the data, and compute various statistical quantities on each bin:

# %%
import numpy as np

# Define pulses per bin
pulsesPerBin = 100

# get an array which tells which bin number an entry belongs to
bin_mask = np.array([i // pulsesPerBin for i in range(len(data.index))])
# get the actual bin boundaries
bins = data.index[[0, ] + (1 + np.where((bin_mask[1:] - bin_mask[0:-1]) == 1)[0]).tolist()]
# group the dataframe
groups = data.groupby(bin_mask)

# %%
# see some statistical properties
groups.describe()
# Out:
#   pulseId                                                               \
#     count         mean      std          min          25%          50%
# 0  60.000 43910850.000 1746.425 43907900.000 43909375.000 43910850.000
#
#                             globalSeconds                   ...      \
#            75%          max         count           mean    ...
# 0 43912325.000 43913800.000        60.000 1469628690.167    ...
#
#   S10CB01-RIQM-DCP10:FOR-PHASE-AVG         globalNanoseconds             \
#                                75%     max             count       mean
# 0                          144.498 144.520            60.000 910850.000
#
#
#        std        min        25%        50%        75%        max
# 0 1746.425 907900.000 909375.000 910850.000 912325.000 913800.000
#
# [1 rows x 56 columns]

# %% [markdown]
# and then plot:
